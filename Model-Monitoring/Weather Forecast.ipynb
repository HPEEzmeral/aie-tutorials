# %% [markdown]
# # Weather Forecast Dataset - Usage Example

# %% [markdown]
# This an example demonstrating the usage of the Weather Forecast Dataset.

# %% [markdown]
# ## Installing the datasets module
#
# Uncomment the cell below if you don't have the `datasets` module installed:

# %%
# Note: you may need to restart the kernel to use updated packages.
# %pip install --proxy http://10.78.90.46:80/ 'whylogs[datasets]'
# Out:
# Requirement already satisfied: whylogs[datasets] in /opt/conda/lib/python3.11/site-packages (1.6.4)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (2.2.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (2.2.3)
# Requirement already satisfied: platformdirs<4.0.0,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (3.11.0)
# Requirement already satisfied: protobuf>=3.19.4 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (4.25.6)
# Requirement already satisfied: requests<3.0,>=2.27 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.10 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (4.12.2)
# Requirement already satisfied: whylabs-client<0.7.0,>=0.6.15 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (0.6.16)
# Requirement already satisfied: whylogs-sketching>=3.4.1.dev3 in /opt/conda/lib/python3.11/site-packages (from whylogs[datasets]) (3.4.1.dev3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.27->whylogs[datasets]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.27->whylogs[datasets]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.27->whylogs[datasets]) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0,>=2.27->whylogs[datasets]) (2025.1.31)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from whylabs-client<0.7.0,>=0.6.15->whylogs[datasets]) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas->whylogs[datasets]) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->whylogs[datasets]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->whylogs[datasets]) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil->whylabs-client<0.7.0,>=0.6.15->whylogs[datasets]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# You can load the dataset of your choice by calling it from the `datasets` module:

# %%
#if you face issue with downloading the dataset, you can cpy data from /whylogs_data/weather_forecast folder

from whylogs.datasets import Weather

dataset = Weather(version="in_domain")

# %% [markdown]
# This will create a folder in the current directory named `whylogs_data` with the csv files for the Weather Dataset. If the files already exist, the module will not redownload the files.
#
# Notice we're specifying the version of the dataset. A dataset can have multiple versions that can be used for differente purposes. In this case, the version "in_domain" has data from the same domain between baseline and inference subsets (data from the same set of regions - tropical, dry, polar, etc.).
#
# If we're interested in assessing drift issues, the version "out_domain" could be used, in which we have out-of-domain data in the inference subset, when compare to the baseline.
#
# Similarly, datasets could have other versions for other purposes, such as assessing data quality or outlier detection strategies.

# %% [markdown]
# ## Discovering Information

# %% [markdown]
# To know what are the available versions for a given dataset, you can call:

# %%
Weather.describe_versions()
# Out:
# ('in_domain', 'out_domain')

# %% [markdown]
# To get access to overall description of the dataset:

# %%
print(Weather.describe()[:1000])

# %% [markdown]
# note: the output was truncated to first 1000 characters as `describe()` will print a rather lengthy description.

# %% [markdown]
# ## Getting Baseline Data

# %% [markdown]
# You can access data from two different partitions: the baseline dataset and inference dataset.
#
# The baseline can be accessed as a whole, whereas the inference dataset can be accessed in periodic batches, defined by the user.
#
# To get a `baseline` object, just call `dataset.get_baseline()`:

# %%
from whylogs.datasets import Weather

dataset = Weather(version="out_domain")

baseline = dataset.get_baseline()

# %% [markdown]
# `baseline` will contain different attributes - one timestamp and five dataframes.
#
# - timestamp: the batch's timestamp (at the start)
# - data: the complete dataframe
# - features: input features
# - target: output feature(s)
# - prediction: output prediction and, possibly, features such as uncertainty, confidence, probability
# - misc: metadata features that are not of any of the previous categories, but still contain relevant information about the data.

# %%
baseline.timestamp
# Out:
# datetime.datetime(2025, 4, 10, 0, 0, tzinfo=datetime.timezone.utc)

# %%
baseline.extra.head()
# Out:
#                            meta_latitude  meta_longitude    meta_climate
# date
# 2025-04-10 00:00:00+00:00      28.702900     -105.964996             dry
# 2025-04-10 00:00:00+00:00     -35.165298      147.466003  mild temperate
# 2025-04-10 00:00:00+00:00      29.607300      -95.158798  mild temperate
# 2025-04-10 00:00:00+00:00      39.077999      -77.557503  mild temperate
# 2025-04-10 00:00:00+00:00      26.152599      -81.775299  mild temperate

# %% [markdown]
# ## Setting Parameters

# %% [markdown]
# With `set_parameters`, you can specify the timestamps for both baseline and inference datasets, as well as the inference interval.
#
# By default, the timestamp is set as:
# - Current date for baseline dataset
# - Tomorrow's date for inference dataset
#
# These timestamps can be defined by the user to any given day, including the dataset's original date.
#
# The `inference_interval` defines the interval for each batch: '1d' means that we will have daily batches, while '7d' would mean weekly batches.

# %% [markdown]
# To set the timestamps to the original dataset's date, set `original` to true, like below:

# %%
# Currently, the inference interval takes a str in the format "Xd", where X is an integer between 1-30
dataset.set_parameters(inference_interval="1d", original=True)
# Out:
# /opt/conda/lib/python3.11/site-packages/whylogs/datasets/utils.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   original_start_date = _validate_timestamp(df["date"][0])
# /opt/conda/lib/python3.11/site-packages/whylogs/datasets/utils.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   original_start_date = _validate_timestamp(df["date"][0])

# %%
baseline = dataset.get_baseline()
baseline.timestamp
# Out:
# datetime.datetime(2018, 9, 1, 0, 0, tzinfo=datetime.timezone.utc)

# %% [markdown]
# You can set timestamp by using the `baseline_timestamp` and `inference_start_timestamp`, and the inference interval like below:

# %%
from datetime import datetime, timezone
now = datetime.now(timezone.utc)
dataset.set_parameters(baseline_timestamp=now, inference_start_timestamp=now, inference_interval="1d")
# Out:
# /opt/conda/lib/python3.11/site-packages/whylogs/datasets/utils.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   original_start_date = _validate_timestamp(df["date"][0])
# /opt/conda/lib/python3.11/site-packages/whylogs/datasets/utils.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   original_start_date = _validate_timestamp(df["date"][0])

# %% [markdown]
# > Note that we are passing the datetime converted to the UTC timezone. If a naive datetime is passed (no information on timezones), local time zone will be assumed. The local timestamp, however, will be converted to the proper datetime in UTC timezone. Passing a naive datetime will trigger a warning, letting you know of this behavior.

# %% [markdown]
# Note that if both `original` and a timestamp (baseline or inference) is passed simultaneously, the defined timestamp will be overwritten by the original dataset timestamp.

# %% [markdown]
# ## Getting Inference Data #1 - By Date

# %% [markdown]
# You can get inference data in two different ways. The first is to specify the exact date you want, which will return a single batch:

# %%
batch = dataset.get_inference_data(target_date=now)

# %% [markdown]
# You can access the attributes just as showed before:

# %%
batch.timestamp
# Out:
# datetime.datetime(2025, 4, 10, 0, 0, tzinfo=datetime.timezone.utc)

# %%
batch.data
# Out:
#                            height_sea_level  sun_elevation    pressure  \
# date
# 2025-04-10 00:00:00+00:00             166.0      24.134473  749.287193
# 2025-04-10 00:00:00+00:00             180.0      36.168942  738.731879
# 2025-04-10 00:00:00+00:00  ...                    0.0            0.0
# 2025-04-10 00:00:00+00:00  ...                    0.0            0.0
#
#                            iced_graupel_grad  cloud_coverage_grad  \
# date
# 2025-04-10 00:00:00+00:00                0.0                 -2.0
# 2025-04-10 00:00:00+00:00                0.0                -23.0
# 2025-04-10 00:00:00+00:00                0.0                  0.0
# 2025-04-10 00:00:00+00:00                0.0                -70.0
# 2025-04-10 00:00:00+00:00                0.0                 -1.0
# ...                                      ...                  ...
# 2025-04-10 00:00:00+00:00                0.0                  0.0
# 2025-04-10 00:00:00+00:00                0.0                 -9.0
# 2025-04-10 00:00:00+00:00                0.0                 30.0
# 2025-04-10 00:00:00+00:00                0.0                 -1.0
# 2025-04-10 00:00:00+00:00                0.0                -26.0
#
#                            meta_latitude  meta_longitude  meta_climate  \
# date
# 2025-04-10 00:00:00+00:00      46.516667       29.483333          snow
# 2025-04-10 00:00:00+00:00      46.521900       26.910299          snow
# 2025-04-10 00:00:00+00:00      39.033333      125.783333          snow
# 2025-04-10 00:00:00+00:00      55.281898      -77.765297          snow
# 2025-04-10 00:00:00+00:00      38.519901      -28.715900         polar
# ...                                  ...             ...           ...
# 2025-04-10 00:00:00+00:00      39.843498      -85.897102          snow
# 2025-04-10 00:00:00+00:00      -5.911420      -35.247700         polar
# 2025-04-10 00:00:00+00:00      58.100000       38.683333          snow
# 2025-04-10 00:00:00+00:00      66.580000      -61.620000         polar
# 2025-04-10 00:00:00+00:00      60.289167        5.226389          snow
#
#                            prediction_temperature  temperature  uncertainty
# date
# 2025-04-10 00:00:00+00:00               17.459501         19.0     5.046475
# 2025-04-10 00:00:00+00:00               15.650873         15.0    10.590467
# 2025-04-10 00:00:00+00:00                9.651232         11.0     5.512176
# 2025-04-10 00:00:00+00:00                7.948395          8.0     3.395677
# 2025-04-10 00:00:00+00:00               18.248093         18.0     2.023753
# ...                                           ...          ...          ...
# 2025-04-10 00:00:00+00:00                8.233539          7.0     5.549324
# 2025-04-10 00:00:00+00:00               30.618527         30.0     2.319395
# 2025-04-10 00:00:00+00:00               16.601422         17.0     4.060273
# 2025-04-10 00:00:00+00:00                1.004967         -1.0     3.510967
# 2025-04-10 00:00:00+00:00                7.546170          7.0     2.232020
#
# [100 rows x 54 columns]

# %%
batch.prediction.head()
# Out:
#                            prediction_temperature  uncertainty
# date
# 2025-04-10 00:00:00+00:00               17.459501     5.046475
# 2025-04-10 00:00:00+00:00               15.650873    10.590467
# 2025-04-10 00:00:00+00:00                9.651232     5.512176
# 2025-04-10 00:00:00+00:00                7.948395     3.395677
# 2025-04-10 00:00:00+00:00               18.248093     2.023753

# %% [markdown]
# ## Getting Inference Data #2 - By Number of Batches

# %% [markdown]
# The second way is to specify the number of batches you want and also the date for the first batch.
#
# You can then iterate over the returned object to get the batches. You can then use the batch any way you want. Here's an example that retrieves daily batches for a period of 5 days and logs each one with __whylogs__, saving the binary profiles to disk:

# %%
import whylogs as why
batches = dataset.get_inference_data(number_batches=5)
for batch in batches:
  print("logging batch of size {} for {}".format(len(batch.data),batch.timestamp))
  profile = why.log(batch.data).profile()
  profile.set_dataset_timestamp(batch.timestamp)
  profile.view().write("batch_{}".format(batch.timestamp), overwrite=True)
